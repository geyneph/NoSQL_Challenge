# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `YOUR IMPORT TEXT HERE`

# %% [markdown]
# - mongosh
# - show dbs
# - use uk_food
# - db.establishments
# - mongoimport: Users/geyne/Desktop/Bootcamp Data An/Challenges/Nosqlchallenge/Resources/establishments.json  -d uk_food -c establishments  --drop

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
mongo.database_names()
# Out:
# /var/folders/fk/cvrcy451067_965x_wm3fkwc0000gn/T/ipykernel_19283/217054031.py:2: DeprecationWarning: database_names is deprecated. Use list_database_names instead.
#   mongo.database_names()
# ['Met', 'admin', 'config', 'dataAnlaysis', 'local', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
db.collection_names()
# Out:
# /var/folders/fk/cvrcy451067_965x_wm3fkwc0000gn/T/ipykernel_19283/1966569860.py:2: DeprecationWarning: collection_names is deprecated. Use list_collection_names instead.
#   db.collection_names()
# ['establishments']

# %%
# review a document in the establishments collection
list(db['establishments'].find())
# Out:
# [{'_id': ObjectId('659cae909b2753f7fd6d1d12'),
#   'FHRSID': 254719,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000069980',
#   'BusinessName': 'Refreshment Kiosk',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'The Bay',
#   'AddressLine2': 'St Margarets Bay',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT15 6DY',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-03-24T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.387974', 'latitude': '51.152225'},
#   'RightToReply': '',
#   'Distance': 4587.347174863443,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/254719'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d13'),
#   'FHRSID': 1034540,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000078691',
#   'BusinessName': 'The Coastguard Inn',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'AddressLine1': 'The Bay',
#   'AddressLine2': 'St Margarets Bay',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT15 6DY',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-08-17T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.387974', 'latitude': '51.152225'},
#   'RightToReply': '',
#   'Distance': 4587.347174863443,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1034540'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d14'),
#   'FHRSID': 254250,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000066174',
#   'BusinessName': 'The Pines Calyx',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': 'The Pines Garden',
#   'AddressLine2': 'Beach Road',
#   'AddressLine3': 'St Margarets Bay',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT15 6DZ',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-08-17T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.383298', 'latitude': '51.148133'},
#   'RightToReply': '',
#   'Distance': 4587.362402580997,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/254250'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d15'),
#   'FHRSID': 551803,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000070948',
#   'BusinessName': 'The Tea Room',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'The Pines Garden',
#   'AddressLine2': 'Beach Road',
#   'AddressLine3': 'St Margarets Bay',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT15 6DZ',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-08-17T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.383298', 'latitude': '51.148133'},
#   'RightToReply': '',
#   'Distance': 4587.362402580997,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/551803'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d16'),
#   'FHRSID': 632212,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000043474',
#   'BusinessName': 'Lenox House',
#   'BusinessType': 'Hotel/bed & breakfast/guest house',
#   'BusinessTypeID': 7842,
#   'AddressLine1': '27 Granville Road',
#   'AddressLine2': 'St Margarets Bay',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT15 6DS',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2020-03-17T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.385585', 'latitude': '51.152411'},
#   'RightToReply': '',
#   'Distance': 4587.440906956158,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/632212'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d17'),
#   'FHRSID': 429991,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000055200',
#   'BusinessName': 'Mrs Knotts Tea Room',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'West Cottage',
#   'AddressLine2': 'South Foreland Lighthouse',
#   'AddressLine3': 'The Front',
#   'AddressLine4': 'St Margarets Bay',
#   'PostCode': 'CT15 6HP',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-05-02T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.371894', 'latitude': '51.14061'},
#   'RightToReply': '',
#   'Distance': 4587.492467848017,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/429991'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d18'),
#   'FHRSID': 1349980,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000084064',
#   'BusinessName': 'Boodles',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': '3 The Droveway',
#   'AddressLine2': 'St Margarets Bay',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT15 6DH',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-06-14T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.378536', 'latitude': '51.150879'},
#   'RightToReply': '',
#   'Distance': 4587.638929767669,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1349980'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d19'),
#   'FHRSID': 1290215,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000083029',
#   'BusinessName': 'FirstLight Bar & Café',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': '1 The Droveway',
#   'AddressLine2': 'St Margarets Bay',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT15 6DH',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2020-11-09T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.378231', 'latitude': '51.150625'},
#   'RightToReply': '',
#   'Distance': 4587.64041272672,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1290215'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d1a'),
#   'FHRSID': 429982,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000043978',
#   'BusinessName': 'The Barn',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Reach Court Farm',
#   'AddressLine2': 'Reach Road',
#   'AddressLine3': 'St Margarets At Cliffe',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT15 6AQ',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2017-09-21T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.371115', 'latitude': '51.147379'},
#   'RightToReply': '',
#   'Distance': 4587.77622109052,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/429982'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d1b'),
#   'FHRSID': 1531040,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000085904',
#   'BusinessName': 'The Halfway Hut',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Walmer And Kingsdown Golf Club',
#   'AddressLine2': 'The Leas',
#   'AddressLine3': 'Kingsdown',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT14 8EP',
#   'Phone': '',
#   'RatingValue': 'AwaitingInspection',
#   'RatingKey': 'fhrs_awaitinginspection_en-gb',
#   'RatingDate': '1901-01-01T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': None,
#    'Structural': None,
#    'ConfidenceInManagement': None},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.4032986', 'latitude': '51.1787284'},
#   'RightToReply': '',
#   'Distance': 4587.792282474894,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1531040'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d1c'),
#   'FHRSID': 1273080,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000082753',
#   'BusinessName': 'Lovetocater',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Walmer And Kingsdown Golf Club',
#   'AddressLine2': 'The Leas',
#   'AddressLine3': 'Kingsdown',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT14 8EP',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-06-23T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.4032986', 'latitude': '51.1787284'},
#   'RightToReply': '',
#   'Distance': 4587.792282474894,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1273080'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d1d'),
#   'FHRSID': 452092,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000040614',
#   'BusinessName': 'Walmer and Kingsdown Golf Club',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'AddressLine1': 'The Leas',
#   'AddressLine2': 'Kingsdown',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT14 8EP',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-09-10T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': None,
#    'Structural': None,
#    'ConfidenceInManagement': None},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.40325689315796', 'latitude': '51.1787300109863'},
#   'RightToReply': '',
#   'Distance': 4587.793855801259,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/452092'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d1e'),
#   'FHRSID': 254410,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000053944',
#   'BusinessName': 'St Margarets At Cliffe C P School',
#   'BusinessType': 'School/college/university',
#   'BusinessTypeID': 7845,
#   'AddressLine1': 'Sea Street',
#   'AddressLine2': 'St Margarets At Cliffe',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT15 6SS',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-01-16T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.375095', 'latitude': '51.152913'},
#   'RightToReply': '',
#   'Distance': 4587.840617011452,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/254410'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d1f'),
#   'FHRSID': 574015,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000069596',
#   'BusinessName': 'St Margarets At Cliffe Nursery And After School Club',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'AddressLine1': 'St Margarets At Cliffe C P School',
#   'AddressLine2': 'Sea Street',
#   'AddressLine3': 'St Margarets At Cliffe',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT15 6SS',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-08-27T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.375095', 'latitude': '51.152913'},
#   'RightToReply': '',
#   'Distance': 4587.840617011452,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/574015'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d20'),
#   'FHRSID': 1030622,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000078259',
#   'BusinessName': 'Portal House School',
#   'BusinessType': 'School/college/university',
#   'BusinessTypeID': 7845,
#   'AddressLine1': 'Sea Street',
#   'AddressLine2': 'St Margarets At Cliffe',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT15 6SS',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-11-13T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.375095', 'latitude': '51.152913'},
#   'RightToReply': '',
#   'Distance': 4587.840617011452,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1030622'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d21'),
#   'FHRSID': 466211,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000070896',
#   'BusinessName': 'The White Cliffs',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'High Street',
#   'AddressLine2': 'St Margarets At Cliffe',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT15 6AT',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-12-03T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.372341', 'latitude': '51.153784'},
#   'RightToReply': '',
#   'Distance': 4587.973462119751,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/466211'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d22'),
#   'FHRSID': 962759,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000077707',
#   'BusinessName': 'The Village Shop',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'AddressLine1': 'High Street',
#   'AddressLine2': 'St Margarets At Cliffe',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT15 6AU',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2020-03-05T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.371543', 'latitude': '51.154023'},
#   'RightToReply': '',
#   'Distance': 4588.011450047919,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/962759'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d23'),
#   'FHRSID': 254731,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000043588',
#   'BusinessName': 'The Smugglers',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'AddressLine1': 'High Street',
#   'AddressLine2': 'St Margarets At Cliffe',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT15 6AU',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-08-17T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.371543', 'latitude': '51.154023'},
#   'RightToReply': '',
#   'Distance': 4588.011450047919,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/254731'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d24'),
#   'FHRSID': 1376311,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000084109',
#   'BusinessName': "St Margaret's Bowls and Social Club",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Bowling Club',
#   'AddressLine2': '13 Kingsdown Road',
#   'AddressLine3': 'St Margarets At Cliffe',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT15 6AZ',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-07-13T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.37213003635406', 'latitude': '51.1558113098145'},
#   'RightToReply': '',
#   'Distance': 4588.057641902885,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1376311'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d25'),
#   'FHRSID': 254239,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000068711',
#   'BusinessName': 'Boat House & Langdon',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'St Margarets Hotel And Country Club',
#   'AddressLine2': 'Reach Road',
#   'AddressLine3': 'St Margarets At Cliffe',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT15 6AG',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-07-01T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.366199', 'latitude': '51.150372'},
#   'RightToReply': '',
#   'Distance': 4588.067654106012,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/254239'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d26'),
#   'FHRSID': 760657,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000074489',
#   'BusinessName': 'The Lounge Bar',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Kingsdown Park Holiday Village',
#   'AddressLine2': 'Upper Street',
#   'AddressLine3': 'Kingsdown',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT14 8EU',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2017-08-11T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 10, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.402478', 'latitude': '51.185258'},
#   'RightToReply': '',
#   'Distance': 4588.0687557014535,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/760657'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d27'),
#   'FHRSID': 1420231,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000084856',
#   'BusinessName': 'Hogbox',
#   'BusinessType': 'Mobile caterer',
#   'BusinessTypeID': 7846,
#   'AddressLine1': 'Kingsdown Park Holiday Village',
#   'AddressLine2': 'Upper Street',
#   'AddressLine3': 'Kingsdown',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT14 8EU',
#   'Phone': '',
#   'RatingValue': 'AwaitingInspection',
#   'RatingKey': 'fhrs_awaitinginspection_en-gb',
#   'RatingDate': '1901-01-01T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': None,
#    'Structural': None,
#    'ConfidenceInManagement': None},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.402478', 'latitude': '51.185258'},
#   'RightToReply': '',
#   'Distance': 4588.0687557014535,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1420231'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d28'),
#   'FHRSID': 1205250,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000081301',
#   'BusinessName': 'Goodwins Suite (Reception)',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'AddressLine1': 'Kingsdown Park Holiday Village',
#   'AddressLine2': 'Upper Street',
#   'AddressLine3': 'Kingsdown',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT14 8EU',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-10-24T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.402478', 'latitude': '51.185258'},
#   'RightToReply': '',
#   'Distance': 4588.0687557014535,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1205250'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d29'),
#   'FHRSID': 1051016,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000078918',
#   'BusinessName': 'Rising Sun',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'AddressLine1': 'Cliffe Road',
#   'AddressLine2': 'Kingsdown',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT14 8AH',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-09-17T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.4032', 'latitude': '51.186118'},
#   'RightToReply': '',
#   'Distance': 4588.075073437313,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1051016'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d2a'),
#   'FHRSID': 522102,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000072342',
#   'BusinessName': 'Zetland Arms',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'AddressLine1': 'Wellington Parade',
#   'AddressLine2': 'Kingsdown',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT14 8AF',
#   'Phone': '',
#   'RatingValue': '3',
#   'RatingKey': 'fhrs_3_en-gb',
#   'RatingDate': '2021-09-30T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 10, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.404353', 'latitude': '51.187776'},
#   'RightToReply': '',
#   'Distance': 4588.095921173912,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/522102'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d2b'),
#   'FHRSID': 799986,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000075312',
#   'BusinessName': 'Seahaven & Kingsdown Lodge',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'AddressLine1': 'Beach House',
#   'AddressLine2': '110 Wellington Parade',
#   'AddressLine3': 'Kingsdown',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT14 8AF',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-07-05T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.4042455', 'latitude': '51.1886588'},
#   'RightToReply': '',
#   'Distance': 4588.13317786893,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/799986'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d2c'),
#   'FHRSID': 607349,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000073098',
#   'BusinessName': 'Oxtale',
#   'BusinessType': 'Manufacturers/packers',
#   'BusinessTypeID': 7839,
#   'AddressLine1': 'The Ox Tale Butchers',
#   'AddressLine2': 'Upper Street',
#   'AddressLine3': 'Kingsdown',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT14 8BJ',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2022-06-22T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 10, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.399856', 'latitude': '51.185027'},
#   'RightToReply': '',
#   'Distance': 4588.155098195237,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/607349'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d2d'),
#   'FHRSID': 254315,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000066967',
#   'BusinessName': 'Kingsdown Pre School',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'AddressLine1': 'St Johns Village Hall',
#   'AddressLine2': 'Upper Street',
#   'AddressLine3': 'Kingsdown',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT14 8BJ',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2017-09-18T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.399856', 'latitude': '51.185028'},
#   'RightToReply': '',
#   'Distance': 4588.155135977967,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/254315'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d2e'),
#   'FHRSID': 254372,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000040981',
#   'BusinessName': 'Kings Head',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'AddressLine1': 'Upper Street',
#   'AddressLine2': 'Kingsdown',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT14 8BJ',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2018-11-16T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.399856', 'latitude': '51.185028'},
#   'RightToReply': '',
#   'Distance': 4588.155135977967,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/254372'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d2f'),
#   'FHRSID': 254344,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000040950',
#   'BusinessName': 'Kingsdown Newsagents',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'AddressLine1': '1 Greenbank',
#   'AddressLine2': 'Upper Street',
#   'AddressLine3': 'Kingsdown',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT14 8BJ',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-12-12T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.399856', 'latitude': '51.185028'},
#   'RightToReply': '',
#   'Distance': 4588.155135977967,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/254344'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d30'),
#   'FHRSID': 254390,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000038162',
#   'BusinessName': 'National Trust White Cliffs',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Visitors Centre',
#   'AddressLine2': 'National Trust',
#   'AddressLine3': 'Langdon Cliffs',
#   'AddressLine4': 'Dover',
#   'PostCode': 'CT16 1HJ',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2018-11-01T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.338963', 'latitude': '51.132101'},
#   'RightToReply': '',
#   'Distance': 4588.367605738605,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/254390'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d31'),
#   'FHRSID': 254227,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000040455',
#   'BusinessName': 'Kingsdown And Ringwould Cofe Primary School',
#   'BusinessType': 'School/college/university',
#   'BusinessTypeID': 7845,
#   'AddressLine1': 'Glen Road',
#   'AddressLine2': 'Kingsdown',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT14 8DD',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2018-09-18T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.395204', 'latitude': '51.186575'},
#   'RightToReply': '',
#   'Distance': 4588.382262530662,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/254227'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d32'),
#   'FHRSID': 452108,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000071385',
#   'BusinessName': 'Kingsdown & Ringwould Breakfast Club',
#   'BusinessType': 'School/college/university',
#   'BusinessTypeID': 7845,
#   'AddressLine1': 'Kingsdown And Ringwould Cofe Primary School',
#   'AddressLine2': 'Glen Road',
#   'AddressLine3': 'Kingsdown',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT14 8DD',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2018-11-12T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.39520394802094', 'latitude': '51.1865768432617'},
#   'RightToReply': '',
#   'Distance': 4588.38233405188,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/452108'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d33'),
#   'FHRSID': 452084,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000024319',
#   'BusinessName': 'Costa Coffee',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Berth 8/9',
#   'AddressLine2': 'Eastern Docks',
#   'AddressLine3': 'Dover',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT16 1JA',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2017-11-14T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.333158', 'latitude': '51.128318'},
#   'RightToReply': '',
#   'Distance': 4588.435903092498,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/452084'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d34'),
#   'FHRSID': 254219,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000054467',
#   'BusinessName': 'W H Smiths',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'AddressLine1': 'Terminal 3',
#   'AddressLine2': 'Eastern Docks',
#   'AddressLine3': 'Dover',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT16 1JA',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2018-10-17T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.333158', 'latitude': '51.128318'},
#   'RightToReply': '',
#   'Distance': 4588.435903092498,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/254219'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d35'),
#   'FHRSID': 430031,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000071360',
#   'BusinessName': 'Spirit of France',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': 'P&O Ferries',
#   'AddressLine2': 'Eastern Docks',
#   'AddressLine3': 'Dover',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT16 1JA',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-06-07T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.333158', 'latitude': '51.128318'},
#   'RightToReply': '',
#   'Distance': 4588.435903092498,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/430031'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d36'),
#   'FHRSID': 254496,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000024155',
#   'BusinessName': 'Pride of Canterbury',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': 'P&O Ferries',
#   'AddressLine2': 'Eastern Docks',
#   'AddressLine3': 'Dover',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT16 1JA',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-09-23T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.333158', 'latitude': '51.128318'},
#   'RightToReply': '',
#   'Distance': 4588.435903092498,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/254496'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d37'),
#   'FHRSID': 452096,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000053923',
#   'BusinessName': 'Burger King',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Terminal 3',
#   'AddressLine2': 'Eastern Docks',
#   'AddressLine3': 'Dover',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT16 1JA',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-11-14T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.333158', 'latitude': '51.128318'},
#   'RightToReply': '',
#   'Distance': 4588.435903092498,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/452096'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d38'),
#   'FHRSID': 254693,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000024150',
#   'BusinessName': 'Pride of Burgundy',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': 'P&O Ferries',
#   'AddressLine2': 'Eastern Docks',
#   'AddressLine3': 'Dover',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT16 1JA',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-12-06T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.333158', 'latitude': '51.128318'},
#   'RightToReply': '',
#   'Distance': 4588.435903092498,
# ...
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 15, 'Structural': 15, 'ConfidenceInManagement': 20},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.17584', 'latitude': '51.07873'},
#   'RightToReply': '',
#   'Distance': 4592.295632854469,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/289489'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d20ee'),
#   'FHRSID': 1172947,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000077241',
#   'BusinessName': "Anna's Tearoom",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Ground Floor Business Premises',
#   'AddressLine2': '23 Cheriton Place',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT20 2AY',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-07-07T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.17584', 'latitude': '51.07873'},
#   'RightToReply': '',
#   'Distance': 4592.295632854469,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1172947'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d20ef'),
#   'FHRSID': 426755,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000030018',
#   'BusinessName': 'Food For Thought',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': '11 Cheriton Place',
#   'AddressLine2': 'Folkestone',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT20 2AY',
#   'Phone': '',
#   'RatingValue': '3',
#   'RatingKey': 'fhrs_3_en-gb',
#   'RatingDate': '2022-07-07T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 10, 'Structural': 10, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.17584', 'latitude': '51.07873'},
#   'RightToReply': '',
#   'Distance': 4592.295632854469,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/426755'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d20f0'),
#   'FHRSID': 1219524,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000032132',
#   'BusinessName': 'Church Of Our Lady Of Christians',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': 'Church Of Our Lady Of Christians And St Aloysius',
#   'AddressLine2': '41A Guildhall Street',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT20 1EF',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-11-26T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.17841398715973', 'latitude': '51.0812644958496'},
#   'RightToReply': '',
#   'Distance': 4592.29696083349,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1219524'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d20f1'),
#   'FHRSID': 552982,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000070468',
#   'BusinessName': 'Three Hills Sports Park',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Pavilion And Sports Hall',
#   'AddressLine2': 'Cheriton Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2017-01-25T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.17725700019713', 'latitude': '51.0806630002457'},
#   'RightToReply': '',
#   'Distance': 4592.316546009465,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/552982'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d20f2'),
#   'FHRSID': 480350,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000027942',
#   'BusinessName': "Sainsbury's",
#   'BusinessType': 'Retailers - supermarkets/hypermarkets',
#   'BusinessTypeID': 7840,
#   'AddressLine1': 'Sainsburys',
#   'AddressLine2': '5 Bouverie Road West',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT20 2SB',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-02-22T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.1748', 'latitude': '51.07856'},
#   'RightToReply': '',
#   'Distance': 4592.327155216805,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/480350'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d20f3'),
#   'FHRSID': 289536,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000037364',
#   'BusinessName': 'Windsor Hotel',
#   'BusinessType': 'Hotel/bed & breakfast/guest house',
#   'BusinessTypeID': 7842,
#   'AddressLine1': '5-6 Langhorne Gardens',
#   'AddressLine2': 'Folkestone',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT20 2EA',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2015-09-23T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 10, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.172728', 'latitude': '51.076647'},
#   'RightToReply': '',
#   'Distance': 4592.330876105803,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/289536'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d20f4'),
#   'FHRSID': 289535,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000037362',
#   'BusinessName': '10 to 12 Folkestone',
#   'BusinessType': 'Hotel/bed & breakfast/guest house',
#   'BusinessTypeID': 7842,
#   'AddressLine1': '10-12 Langhorne Gardens',
#   'AddressLine2': 'Folkestone',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT20 2EA',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-08-20T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 0, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.172728', 'latitude': '51.076647'},
#   'RightToReply': '',
#   'Distance': 4592.330876105803,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/289535'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d20f5'),
#   'FHRSID': 289537,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000037365',
#   'BusinessName': 'Portland Hotel & Skuba',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'AddressLine1': '2-4 Langhorne Gardens',
#   'AddressLine2': 'Folkestone',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT20 2EA',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2020-09-01T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.172728', 'latitude': '51.076647'},
#   'RightToReply': '',
#   'Distance': 4592.330876105803,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/289537'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d20f6'),
#   'FHRSID': 289516,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000035257',
#   'BusinessName': 'The Little Fish & Chip Shop',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'AddressLine1': '62 Canterbury Road',
#   'AddressLine2': 'Folkestone',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT19 5NL',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2016-10-31T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.18431', 'latitude': '51.088115'},
#   'RightToReply': '',
#   'Distance': 4592.339299517761,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/289516'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d20f7'),
#   'FHRSID': 894598,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000074407',
#   'BusinessName': 'Folkestone Rainbow Centre Pre-school',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'AddressLine1': 'Salvation Army Citadel',
#   'AddressLine2': '75-79 Canterbury Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT19 5NL',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2018-09-13T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 0, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.18431', 'latitude': '51.088115'},
#   'RightToReply': '',
#   'Distance': 4592.339299517761,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/894598'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d20f8'),
#   'FHRSID': 1023910,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000075939',
#   'BusinessName': 'Bengal Spice',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'AddressLine1': 'Ground Floor Business Premises',
#   'AddressLine2': '73 Canterbury Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT19 5NL',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-07-18T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.18431', 'latitude': '51.088115'},
#   'RightToReply': '',
#   'Distance': 4592.339299517761,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1023910'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d20f9'),
#   'FHRSID': 1159687,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000077229',
#   'BusinessName': "Roots 'n' Fruits",
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'AddressLine1': 'Ground Floor Business Premises',
#   'AddressLine2': '73 Canterbury Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT19 5NL',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-07-18T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.18431', 'latitude': '51.088115'},
#   'RightToReply': '',
#   'Distance': 4592.339299517761,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1159687'}]},
#  ...]

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
dic1 = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(dic1)

# %%
# Check that the new restaurant was inserted
list(establishments.find({"BusinessName":"Penang Flavours"}))
# Out:
# [{'_id': ObjectId('659caeb4ec2d37267f149f07'),
#   'BusinessName': 'Penang Flavours',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': '',
#   'AddressLine1': 'Penang Flavours',
#   'AddressLine2': '146A Plumstead Rd',
#   'AddressLine3': 'London',
#   'AddressLine4': '',
#   'PostCode': 'SE18 7DY',
#   'Phone': '',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'},
#   'RightToReply': '',
#   'Distance': 4623.972328074718,
#   'NewRatingPending': True}]

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
list(establishments.find({'BusinessType': 'Restaurant/Cafe/Canteen'},{'BusinessTypeID':1,'BusinessType':1}))
# Out:
# [{'_id': ObjectId('659cae909b2753f7fd6d1d12'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d15'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d17'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d18'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d19'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d1a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d1b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d1c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d21'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d24'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d25'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d26'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d30'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d33'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d37'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d42'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d44'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d46'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d47'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d4a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d4b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d50'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d51'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d53'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d54'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d55'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d56'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d5c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d5d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d60'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d64'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d65'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d66'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d69'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d6b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d6c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d77'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d78'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d7f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d80'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d81'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d84'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d86'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d87'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d8c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d94'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d95'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d98'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d9c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d9d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1d9e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1da0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1da1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1da7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1dae'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1daf'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1db3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1db7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1dbd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1dbf'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1dc1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1dc2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1dc3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1dcd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1dce'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1dd3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1dd6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1ddb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1ddd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1dde'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1de3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1de9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1deb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1df1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1dfe'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e00'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e01'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e02'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e0e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e11'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e12'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e14'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e17'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e24'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e25'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e2a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e30'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e32'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e34'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e3b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e40'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e47'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e4c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e4d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e4e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e50'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e55'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e58'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e5a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e5b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e5c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e5f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e60'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e61'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e64'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e65'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e66'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e67'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e69'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e70'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e71'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e7a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e7c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e80'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e81'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e84'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e8b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e8d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e8e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e8f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e90'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e93'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e97'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e9b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e9c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1e9d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1eab'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1eac'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1eae'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1eb3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1eb4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1ebb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1ebd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1ec0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1ec1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1ec9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1ecb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1ed3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1ed8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1eda'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1edc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1edf'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1ee2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1ee6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1eec'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1ef7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1f03'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1f0d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1f2b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1f35'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1f36'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1f39'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1f3c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1f3f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1f4d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1f61'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1f79'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1f7d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1f89'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1f8b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1f8d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1f8f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1f9e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1faa'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1fab'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1fb0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1fb4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1fb7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1fb9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1fbf'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1fc0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1fc5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1fc8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1fc9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1fce'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1fd8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1fd9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1fdc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1fe9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1fee'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1fef'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1ff4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d1ff9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2004'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2008'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d200c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d200d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d201c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2022'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2025'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2029'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d202a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d202d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d202e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d203e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2045'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2047'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d204d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2051'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2052'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2055'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2057'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d205a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d205c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d205d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d205e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d205f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2066'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2068'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2069'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d206e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2070'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2071'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2072'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2077'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2079'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2082'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2083'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2085'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2089'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d208a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d208d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d208e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2092'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2096'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2097'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2099'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d209b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d209f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d20a0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d20a2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d20a6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d20a8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d20ac'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d20ad'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d20b2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d20b5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d20b7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d20bf'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d20c0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d20c2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d20ca'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d20cb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d20cc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d20d2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d20d4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d20d6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d20d8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d20de'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d20df'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d20e1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d20e2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d20e3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d20e4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d20e7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d20ec'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d20ee'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d20ef'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d20f1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d20fe'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d20ff'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2102'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2103'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2105'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d210b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d210c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d210d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d210f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2111'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2113'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2114'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d211a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d211d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d211f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2125'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d212f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2132'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2147'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d214b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d214d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2154'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2155'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2159'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d215d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2171'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2179'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d217c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d217d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d217e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2181'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d218b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d218e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d218f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2190'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2191'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2192'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2193'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2196'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2197'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2198'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2199'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d219a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d21a0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d21aa'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d21ad'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d21b1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d21b2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d21b3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d21b4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d21b5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d21b6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d21b8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d21b9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d21bb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d21be'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d21c0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d21c4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d21c6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d21ce'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d21cf'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d21d0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d21d1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d21d2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d21d3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d21d8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d21d9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d21e4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d21e5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d21e7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d21e8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d21ea'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d21ec'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d21f5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d21f9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d21fb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2200'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2202'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2207'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2209'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d220a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d220d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2215'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d221b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2221'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2226'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2229'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d222b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d222f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2232'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2235'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d223d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2241'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2244'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2245'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2247'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2248'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d224c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2252'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2255'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2256'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2259'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2260'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2263'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2265'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2269'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d226c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d226d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d226e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d226f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2270'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2271'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2273'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2274'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2276'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2277'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d227a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d227b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d227c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d227d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d227f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2282'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2283'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2284'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2285'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2287'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2288'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2289'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d228b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d228c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d228f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2291'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d2299'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d229b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d229c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d229d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d229e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d22a0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d22a8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d22a9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d22ac'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d22ae'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d22b0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d22b5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d22b7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d22be'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d22c0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d22cd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d22d7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d22df'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d22e4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d22e7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d22e9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d22ec'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae909b2753f7fd6d22f4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
# ...
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2953'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2955'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2956'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d295b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d295f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d296d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d296f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2973'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d297a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d297f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2980'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2985'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2993'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2996'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d299a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d29a6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d29ac'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d29ad'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d29b7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d29ba'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d29cc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d29d1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d29d2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d29d3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d29d5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d29da'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d29dc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d29e7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d29ed'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d29f1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d29f7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d29fe'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2a06'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2a19'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2a1f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2a25'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2a2a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2a2c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2a34'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2a35'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2a3d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2a42'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2a43'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2a50'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2a52'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2a56'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2a5a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2a5c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2a5f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2a66'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2a77'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2a87'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2a91'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2a92'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2a94'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2a98'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2a99'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2a9c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2a9e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2aa1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2aa8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2aa9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2ab3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2ab5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2ab6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2ab8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2ab9'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2abd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2abf'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2ac3'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2ac4'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2ac6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2ac7'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2ac8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2aca'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2acb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2acd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2acf'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2ad0'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2ad2'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2ad5'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2adb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2adc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2aeb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2aec'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2aee'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2af1'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2af6'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2af8'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2afb'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2afc'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2afd'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2aff'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b05'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b07'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b09'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b0a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b16'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b19'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b1a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b1b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b1d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b21'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b24'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b25'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b26'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b27'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b28'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b2a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b2e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b31'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b33'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b36'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b38'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b39'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b3c'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b3f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b42'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b49'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b4b'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b4f'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b52'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b53'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b54'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b56'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b58'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b5a'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b5d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b60'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b62'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b63'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b66'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b67'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b68'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b69'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b6d'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  {'_id': ObjectId('659cae919b2753f7fd6d2b6e'),
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1},
#  ...]

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID

establishments.update_one({'BusinessName': 'Penang Flavours'},{'$set':{'BusinessTypeID':1} })

# %%
# Confirm that the new restaurant was updated
list(establishments.find({'BusinessName': 'Penang Flavours'},{'BusinessName':1,'BusinessTypeID':1}))
# Out:
# [{'_id': ObjectId('659caeb4ec2d37267f149f07'),
#   'BusinessName': 'Penang Flavours',
#   'BusinessTypeID': 1}]

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
establishments.count_documents({'LocalAuthorityName':"Dover"})
# Out:
# 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
establishments.delete_many({'LocalAuthorityName':"Dover"})

# %%
# Check if any remaining documents include Dover
establishments.count_documents({'LocalAuthorityName':"Dover"})
# Out:
# 0

# %%
# Check that other documents remain with 'find_one'
list(establishments.find_one({'LocalAuthorityName':"Dover"}))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 2
#       1 # Check that other documents remain with 'find_one'
# ----> 2 list(establishments.find_one({'LocalAuthorityName':"Dover"}))
#
# TypeError: 'NoneType' object is not iterable

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
establishments.update_many(
    {},
    [{"$set":
        {'geocode.latitude': {'$toDouble':'$geocode.latitude'}, 
         'geocode.longitude': {'$toDouble':'$geocode.longitude'}}
     }
    ]
)

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])

# %%
# Change the data type from String to Integer for RatingValue

establishments.update_many(
    {},
    [{
    '$set':{
        'RatingValue':{'$toInt':'$RatingValue'}
    }
    }])

# %%
# Check that the coordinates and rating value are now numbers

list(establishments.find({}))
# Out:
# [{'_id': ObjectId('659cae909b2753f7fd6d1ff9'),
#   'FHRSID': 1043695,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000073616',
#   'BusinessName': 'The Pavilion',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'East Cliff Pavilion',
#   'AddressLine2': 'Wear Bay Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT19 6BL',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2018-04-04T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.195625, 'latitude': 51.083812},
#   'RightToReply': '',
#   'Distance': 4591.765489457773,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1ffa'),
#   'FHRSID': 647177,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000041489',
#   'BusinessName': 'Wear Bay Bowls Club',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'AddressLine1': 'Wear Bay Road',
#   'AddressLine2': 'Folkestone',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT19 6PY',
#   'Phone': '',
#   'RatingValue': 4,
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2014-03-31T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.196408, 'latitude': 51.086058},
#   'RightToReply': '',
#   'Distance': 4591.821311183521,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/647177'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1ffb'),
#   'FHRSID': 289353,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000002468',
#   'BusinessName': 'St Marys COE (aided) Primary School',
#   'BusinessType': 'School/college/university',
#   'BusinessTypeID': 7845,
#   'AddressLine1': 'St Marys Church Of England Primary School',
#   'AddressLine2': 'Warren Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT19 6QH',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2016-09-13T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.194762, 'latitude': 51.085797},
#   'RightToReply': '',
#   'Distance': 4591.871474174837,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/289353'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1ffe'),
#   'FHRSID': 289352,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000002460',
#   'BusinessName': 'The Ship',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'AddressLine1': '23 The Stade',
#   'AddressLine2': 'Folkestone',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT19 6AB',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2015-08-27T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.188537, 'latitude': 51.08084},
#   'RightToReply': '',
#   'Distance': 4591.912144538092,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/289352'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d1fff'),
#   'FHRSID': 289560,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000039927',
#   'BusinessName': 'Mariner',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'AddressLine1': '16 The Stade',
#   'AddressLine2': 'Folkestone',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT19 6AB',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-03-19T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.188537, 'latitude': 51.08084},
#   'RightToReply': '',
#   'Distance': 4591.912144538092,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/289560'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d2000'),
#   'FHRSID': 987206,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000075655',
#   'BusinessName': 'The Ships Galley',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'AddressLine1': 'The Ship',
#   'AddressLine2': '23 The Stade',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT19 6AB',
#   'Phone': '',
#   'RatingValue': 4,
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2019-07-03T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.188537, 'latitude': 51.08084},
#   'RightToReply': '',
#   'Distance': 4591.912144538092,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/987206'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d2001'),
#   'FHRSID': 344689,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000002095',
#   'BusinessName': 'Folkestone Trawlers Shop',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'AddressLine1': '1 The Stade',
#   'AddressLine2': 'Folkestone',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT19 6AB',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2020-02-14T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.188537, 'latitude': 51.08084},
#   'RightToReply': '',
#   'Distance': 4591.912144538092,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/344689'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d2002'),
#   'FHRSID': 894592,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000074396',
#   'BusinessName': 'Docker',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2018-04-18T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076},
#   'RightToReply': '',
#   'Distance': 4591.914705329384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/894592'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d2003'),
#   'FHRSID': 1043701,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000076360',
#   'BusinessName': 'Pick Up Pintxos',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2018-04-18T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076},
#   'RightToReply': '',
#   'Distance': 4591.914705329384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1043701'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d2004'),
#   'FHRSID': 805702,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000073219',
#   'BusinessName': 'Dr Legumes - Harbour Arm',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': 4,
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2018-06-08T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 10, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076},
#   'RightToReply': '',
#   'Distance': 4591.914705329384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/805702'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d2005'),
#   'FHRSID': 805703,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000073221',
#   'BusinessName': 'That Burger - Harbour Arm',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2018-08-17T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076},
#   'RightToReply': '',
#   'Distance': 4591.914705329384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/805703'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d2006'),
#   'FHRSID': 1071930,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000076531',
#   'BusinessName': 'The Club Hut',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2018-08-04T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076},
#   'RightToReply': '',
#   'Distance': 4591.914705329384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1071930'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d2007'),
#   'FHRSID': 1068284,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000076532',
#   'BusinessName': 'The Tea Caddy',
#   'BusinessType': 'Mobile caterer',
#   'BusinessTypeID': 7846,
#   'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2018-08-03T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076},
#   'RightToReply': '',
#   'Distance': 4591.914705329384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1068284'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d2008'),
#   'FHRSID': 1046418,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000076426',
#   'BusinessName': 'Custom Folkestone',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2018-11-30T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076},
#   'RightToReply': '',
#   'Distance': 4591.914705329384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1046418'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d2009'),
#   'FHRSID': 1423242,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000078141',
#   'BusinessName': 'Little Rock',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-04-14T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': None,
#    'Structural': None,
#    'ConfidenceInManagement': None},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076},
#   'RightToReply': '',
#   'Distance': 4591.914705329384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1423242'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d200a'),
#   'FHRSID': 1495230,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000078175',
#   'BusinessName': 'Lobster & Burger',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-04-05T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076},
#   'RightToReply': '',
#   'Distance': 4591.914705329384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1495230'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d200b'),
#   'FHRSID': 1299500,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000078051',
#   'BusinessName': 'The Pilot',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-06-14T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076},
#   'RightToReply': '',
#   'Distance': 4591.914705329384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1299500'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d200c'),
#   'FHRSID': 1396943,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000078121',
#   'BusinessName': 'Barney & The Pizza',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': 3,
#   'RatingKey': 'fhrs_3_en-gb',
#   'RatingDate': '2021-06-06T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 10, 'Structural': 10, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076},
#   'RightToReply': '',
#   'Distance': 4591.914705329384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1396943'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d200d'),
#   'FHRSID': 1396944,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000078122',
#   'BusinessName': "Dino's",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': 4,
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2021-06-06T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 10, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076},
#   'RightToReply': '',
#   'Distance': 4591.914705329384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1396944'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d200e'),
#   'FHRSID': 1058634,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000076448',
#   'BusinessName': 'Platform Three',
#   'BusinessType': 'Mobile caterer',
#   'BusinessTypeID': 7846,
#   'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': 3,
#   'RatingKey': 'fhrs_3_en-gb',
#   'RatingDate': '2018-08-03T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 10, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076},
#   'RightToReply': '',
#   'Distance': 4591.914705329384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1058634'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d200f'),
#   'FHRSID': 861820,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000074300',
#   'BusinessName': 'Waiting Room - Harbour Arm',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-07-12T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076},
#   'RightToReply': '',
#   'Distance': 4591.914705329384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/861820'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d2010'),
#   'FHRSID': 873838,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000074304',
#   'BusinessName': 'Hog & Hop - Harbour Arm',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-07-12T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076},
#   'RightToReply': '',
#   'Distance': 4591.914705329384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/873838'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d2011'),
#   'FHRSID': 1495226,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000078171',
#   'BusinessName': 'The Dessert Junction',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-04-20T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076},
#   'RightToReply': '',
#   'Distance': 4591.914705329384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1495226'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d2012'),
#   'FHRSID': 1410251,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000078140',
#   'BusinessName': 'Fish Shack',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-04-20T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076},
#   'RightToReply': '',
#   'Distance': 4591.914705329384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1410251'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d2013'),
#   'FHRSID': 1241758,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000077661',
#   'BusinessName': 'Coffee Folkes',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-04-28T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076},
#   'RightToReply': '',
#   'Distance': 4591.914705329384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1241758'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d2014'),
#   'FHRSID': 1466503,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000078160',
#   'BusinessName': 'Greek Street',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-04-28T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076},
#   'RightToReply': '',
#   'Distance': 4591.914705329384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1466503'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d2015'),
#   'FHRSID': 1389679,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000078117',
#   'BusinessName': 'Harbour Hotdogs/Meatshack',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-04-28T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076},
#   'RightToReply': '',
#   'Distance': 4591.914705329384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1389679'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d2016'),
#   'FHRSID': 1401066,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000078134',
#   'BusinessName': 'A Hui Hou',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': 2,
#   'RatingKey': 'fhrs_2_en-gb',
#   'RatingDate': '2021-08-13T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 15, 'Structural': 15, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076},
#   'RightToReply': '',
#   'Distance': 4591.914705329384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1401066'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d2017'),
#   'FHRSID': 1058636,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000076450',
#   'BusinessName': 'Babaji',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': 4,
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2021-08-13T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': None,
#    'Structural': None,
#    'ConfidenceInManagement': None},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076},
#   'RightToReply': '',
#   'Distance': 4591.914705329384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1058636'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d2018'),
#   'FHRSID': 861815,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000073853',
#   'BusinessName': 'Bath Tub and Gun - Harbour Arm',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-07-26T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076},
#   'RightToReply': '',
#   'Distance': 4591.914705329384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/861815'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d2019'),
#   'FHRSID': 1138444,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000077128',
#   'BusinessName': 'Lucky Radish',
#   'BusinessType': 'Mobile caterer',
#   'BusinessTypeID': 7846,
#   'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': 4,
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2019-07-26T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 10, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076},
#   'RightToReply': '',
#   'Distance': 4591.914705329384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1138444'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d201a'),
#   'FHRSID': 1401065,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000078133',
#   'BusinessName': 'Shesells Seashells',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-09-26T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076},
#   'RightToReply': '',
#   'Distance': 4591.914705329384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1401065'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d201b'),
#   'FHRSID': 865873,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000074303',
#   'BusinessName': 'Sole Kitchen - Harbour Arm',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': 4,
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2021-10-03T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 10, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076},
#   'RightToReply': '',
#   'Distance': 4591.914705329384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/865873'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d201c'),
#   'FHRSID': 1058635,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000076449',
#   'BusinessName': 'Harbour Coffee Company',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-10-03T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076},
#   'RightToReply': '',
#   'Distance': 4591.914705329384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1058635'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d201d'),
#   'FHRSID': 1401064,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000078132',
#   'BusinessName': 'Burrito Buoy',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-10-03T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076},
#   'RightToReply': '',
#   'Distance': 4591.914705329384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1401064'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d201e'),
#   'FHRSID': 1427428,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000078143',
#   'BusinessName': 'The Taco Shed',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': 2,
#   'RatingKey': 'fhrs_2_en-gb',
#   'RatingDate': '2021-06-06T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 10, 'Structural': 15, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076},
#   'RightToReply': '',
#   'Distance': 4591.914705329384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1427428'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d201f'),
#   'FHRSID': 1245690,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000077672',
#   'BusinessName': 'The Big Greek Bus',
#   'BusinessType': 'Mobile caterer',
#   'BusinessTypeID': 7846,
#   'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-05-09T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076},
#   'RightToReply': '',
#   'Distance': 4591.914705329384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1245690'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d2020'),
#   'FHRSID': 1519633,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000078214',
#   'BusinessName': 'Go Dutch',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-05-26T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076},
#   'RightToReply': '',
#   'Distance': 4591.914705329384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
# ...
#   'FHRSID': 637692,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000041930',
#   'BusinessName': 'Sea Master',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'AddressLine1': '94 Albion Road',
#   'AddressLine2': 'Broadstairs',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT10 2UT',
#   'Phone': '',
#   'RatingValue': 4,
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2022-06-08T00:00:00',
#   'LocalAuthorityCode': '190',
#   'LocalAuthorityName': 'Thanet',
#   'LocalAuthorityWebSite': 'http://www.thanet.gov.uk',
#   'LocalAuthorityEmailAddress': 'environmental.health@thanet.gov.uk',
#   'scores': {'Hygiene': 10, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.42351, 'latitude': 51.367482},
#   'RightToReply': '',
#   'Distance': 4594.201353894907,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/637692'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d2463'),
#   'FHRSID': 997375,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000098721',
#   'BusinessName': 'May King',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'AddressLine1': '96 Albion Road',
#   'AddressLine2': 'Broadstairs',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT10 2UT',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-08-31T00:00:00',
#   'LocalAuthorityCode': '190',
#   'LocalAuthorityName': 'Thanet',
#   'LocalAuthorityWebSite': 'http://www.thanet.gov.uk',
#   'LocalAuthorityEmailAddress': 'environmental.health@thanet.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.42351, 'latitude': 51.367482},
#   'RightToReply': '',
#   'Distance': 4594.201353894907,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/997375'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d2464'),
#   'FHRSID': 658491,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000030203',
#   'BusinessName': 'Best Moon Shop',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'AddressLine1': '57 Newington Road',
#   'AddressLine2': 'Ramsgate',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT12 6EX',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2020-02-26T00:00:00',
#   'LocalAuthorityCode': '190',
#   'LocalAuthorityName': 'Thanet',
#   'LocalAuthorityWebSite': 'http://www.thanet.gov.uk',
#   'LocalAuthorityEmailAddress': 'environmental.health@thanet.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.398588, 'latitude': 51.343957},
#   'RightToReply': '',
#   'Distance': 4594.21035015057,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/658491'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d2465'),
#   'FHRSID': 950455,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000104915',
#   'BusinessName': 'McColls',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'AddressLine1': '112-114 Newington Road',
#   'AddressLine2': 'Ramsgate',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT12 6EX',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-07-08T00:00:00',
#   'LocalAuthorityCode': '190',
#   'LocalAuthorityName': 'Thanet',
#   'LocalAuthorityWebSite': 'http://www.thanet.gov.uk',
#   'LocalAuthorityEmailAddress': 'environmental.health@thanet.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.398588, 'latitude': 51.343957},
#   'RightToReply': '',
#   'Distance': 4594.21035015057,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/950455'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d2466'),
#   'FHRSID': 991877,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000101872',
#   'BusinessName': 'The Red Lion',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'AddressLine1': '2 High Street',
#   'AddressLine2': 'St Peters',
#   'AddressLine3': 'Broadstairs',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT10 2TQ',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-10-08T00:00:00',
#   'LocalAuthorityCode': '190',
#   'LocalAuthorityName': 'Thanet',
#   'LocalAuthorityWebSite': 'http://www.thanet.gov.uk',
#   'LocalAuthorityEmailAddress': 'environmental.health@thanet.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.420118, 'latitude': 51.364585},
#   'RightToReply': '',
#   'Distance': 4594.214032147384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/991877'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d2467'),
#   'FHRSID': 620160,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000041901',
#   'BusinessName': 'Village Newsagents',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'AddressLine1': '12B High Street',
#   'AddressLine2': 'St Peters',
#   'AddressLine3': 'Broadstairs',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT10 2TQ',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2020-01-14T00:00:00',
#   'LocalAuthorityCode': '190',
#   'LocalAuthorityName': 'Thanet',
#   'LocalAuthorityWebSite': 'http://www.thanet.gov.uk',
#   'LocalAuthorityEmailAddress': 'environmental.health@thanet.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.420118, 'latitude': 51.364585},
#   'RightToReply': '',
#   'Distance': 4594.214032147384,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/620160'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d2468'),
#   'FHRSID': 647179,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000071914',
#   'BusinessName': 'Hawkinge Under Five Pre-School',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'AddressLine1': 'The Pavilion',
#   'AddressLine2': 'Pavilion Road',
#   'AddressLine3': 'Hawkinge',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT18 7UA',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2014-03-13T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.1688388, 'latitude': 51.1230953},
#   'RightToReply': '',
#   'Distance': 4594.216048616293,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/647179'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d2469'),
#   'FHRSID': 289753,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000067855',
#   'BusinessName': 'Hawkinge Community Football & Sports',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'The Pavilion',
#   'AddressLine2': 'Pavilion Road',
#   'AddressLine3': 'Hawkinge',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT18 7UA',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-07-28T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.1688388, 'latitude': 51.1230953},
#   'RightToReply': '',
#   'Distance': 4594.216048616293,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/289753'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d246b'),
#   'FHRSID': 620153,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000037236',
#   'BusinessName': 'Callis Grange Breakfast Club',
#   'BusinessType': 'School/college/university',
#   'BusinessTypeID': 7845,
#   'AddressLine1': 'Callis Grange N And I School',
#   'AddressLine2': 'Beacon Road',
#   'AddressLine3': 'Broadstairs',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT10 3DG',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2020-11-10T00:00:00',
#   'LocalAuthorityCode': '190',
#   'LocalAuthorityName': 'Thanet',
#   'LocalAuthorityWebSite': 'http://www.thanet.gov.uk',
#   'LocalAuthorityEmailAddress': 'environmental.health@thanet.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.426555, 'latitude': 51.370928},
#   'RightToReply': '',
#   'Distance': 4594.222013662475,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/620153'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d246c'),
#   'FHRSID': 637689,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000041793',
#   'BusinessName': 'Callis Grange County Primary School',
#   'BusinessType': 'School/college/university',
#   'BusinessTypeID': 7845,
#   'AddressLine1': 'Beacon Road',
#   'AddressLine2': 'Broadstairs',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT10 3DG',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2020-11-20T00:00:00',
#   'LocalAuthorityCode': '190',
#   'LocalAuthorityName': 'Thanet',
#   'LocalAuthorityWebSite': 'http://www.thanet.gov.uk',
#   'LocalAuthorityEmailAddress': 'environmental.health@thanet.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.426555, 'latitude': 51.370928},
#   'RightToReply': '',
#   'Distance': 4594.222013662475,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/637689'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d246d'),
#   'FHRSID': 1034372,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000105799',
#   'BusinessName': 'Rams News',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'AddressLine1': 'The Shop',
#   'AddressLine2': '73 Newington Road',
#   'AddressLine3': 'Ramsgate',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT12 6PP',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-05-09T00:00:00',
#   'LocalAuthorityCode': '190',
#   'LocalAuthorityName': 'Thanet',
#   'LocalAuthorityWebSite': 'http://www.thanet.gov.uk',
#   'LocalAuthorityEmailAddress': 'environmental.health@thanet.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.39900100231171, 'latitude': 51.3446922302246},
#   'RightToReply': '',
#   'Distance': 4594.2232578626645,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1034372'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d246e'),
#   'FHRSID': 637596,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000008672',
#   'BusinessName': 'Newlyn House Residential Home',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'AddressLine1': '2 Cliftonville Avenue',
#   'AddressLine2': 'Ramsgate',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT12 6DS',
#   'Phone': '',
#   'RatingValue': 4,
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2021-08-03T00:00:00',
#   'LocalAuthorityCode': '190',
#   'LocalAuthorityName': 'Thanet',
#   'LocalAuthorityWebSite': 'http://www.thanet.gov.uk',
#   'LocalAuthorityEmailAddress': 'environmental.health@thanet.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 10, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.400038, 'latitude': 51.345885},
#   'RightToReply': '',
#   'Distance': 4594.230948776129,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/637596'}]},
#  {'_id': ObjectId('659cae909b2753f7fd6d246f'),
#   'FHRSID': 895508,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000104438',
#   'BusinessName': 'Yard of Ale',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'AddressLine1': '61 Church Street',
#   'AddressLine2': 'Broadstairs',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT10 2TU',
#   'Phone': '',
#   'RatingValue': 5,
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-02-23T00:00:00',
#   'LocalAuthorityCode': '190',
#   'LocalAuthorityName': 'Thanet',
#   'LocalAuthorityWebSite': 'http://www.thanet.gov.uk',
#   'LocalAuthorityEmailAddress': 'environmental.health@thanet.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': 1.422304, 'latitude': 51.367121},
#   'RightToReply': '',
#   'Distance': 4594.2311943159475,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/895508'}]},
#  ...]
